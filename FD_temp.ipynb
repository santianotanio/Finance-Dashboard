# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ms = pd.read_csv('/run/media/santianotanio/Shared/FINANCE DASHBOARD/monthly_summary.csv')
cs = pd.read_csv('/run/media/santianotanio/Shared/FINANCE DASHBOARD/category_summary.csv')
ld = pd.read_csv('/run/media/santianotanio/Shared/FINANCE DASHBOARD/finance_dashboard_large_dataset.csv')

# %%
ld.head()
# Out:
#   Transaction_ID        Date Account_ID Transaction_Type         Category  \
# 0    TXN-0064261  2021-01-01   ACC-1008           Income       Investment
# 1    TXN-0142813  2021-01-01   ACC-1001          Expense  Cash Withdrawal
# 2    TXN-0142832  2021-01-01   ACC-1001          Expense             Rent
# 3    TXN-0234412  2021-01-01   ACC-1005          Expense        Groceries
# 4    TXN-0234538  2021-01-01   ACC-1004          Expense        Groceries
#
#          Merchant  Amount_INR Payment_Method       City     Status    Month  \
# 0           Groww    13792.92     Debit Card     Jaipur  Completed  2021-01
# 1             ATM      642.42    Credit Card       Pune  Completed  2021-01
# 2      House Rent    19205.49            UPI    Chennai  Completed  2021-01
# 3  Reliance Fresh      958.33    Net Banking  Hyderabad  Completed  2021-01
# 4  Reliance Fresh      557.06            UPI     Jaipur  Completed  2021-01
#
#    Year Quarter Weekday
# 0  2021      Q1  Friday
# 1  2021      Q1  Friday
# 2  2021      Q1  Friday
# 3  2021      Q1  Friday
# 4  2021      Q1  Friday

# %%
ld['Category'].value_counts()
# Out:
# Category
# Groceries          24575
# Salary             24419
# Shopping           19544
# Rent               16966
# Dining             16946
# Transport          16935
# Investment         14560
# Utilities          14541
# Transfer           14436
# Entertainment      12047
# Loan EMI           12043
# Subscriptions      11070
# Freelance           9891
# Travel              9696
# Other               7272
# Cash Withdrawal     7123
# Education           6025
# Insurance           5997
# Healthcare          5914
# Name: count, dtype: int64

# %%
ld['Category']
# Out:
# 0              Investment
# 1         Cash Withdrawal
# 2                    Rent
# 3               Groceries
# 4               Groceries
#                ...
# 249995           Shopping
# 249996          Groceries
# 249997          Transport
# 249998          Freelance
# 249999             Travel
# Name: Category, Length: 250000, dtype: str
