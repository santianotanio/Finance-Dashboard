# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ms = pd.read_csv('/run/media/santianotanio/Shared/FINANCE DASHBOARD/monthly_summary.csv')
cs = pd.read_csv('/run/media/santianotanio/Shared/FINANCE DASHBOARD/category_summary.csv')
ld = pd.read_csv('/run/media/santianotanio/Shared/FINANCE DASHBOARD/finance_dashboard_large_dataset.csv')

# %%
def cat():
    plt.barh(ld['Category'].value_counts().index,ld['Category'].value_counts().values)
    plt.tight_layout()

# %%
info = ld.shape
print('Total number of transactions: ', info[0])
tt = ld.groupby('Transaction_Type')
ex = tt.get_group('Expense')
ic = tt.get_group('Income')
print('Total number of expense transactions: ',ex.shape[0])
print('Total number of income transactions: ',ic.shape[0])
# Out:
# Total number of transactions:  250000
# Total number of expense transactions:  201130
# Total number of income transactions:  48870

# %%
i = int(input('Enter number if the option that you want to access: '))
cat()
